# %%
from langchain_openai import OpenAIEmbeddings
from langchain_chroma import Chroma
from langchain_core.documents import Document

# %%
# Create LangChain documents for IPL players

doc1 = Document(
        page_content="Virat Kohli is one of the most successful and consistent batsmen in IPL history. Known for his aggressive batting style and fitness, he has led the Royal Challengers Bangalore in multiple seasons.",
        metadata={"team": "Royal Challengers Bangalore"}
    )
doc2 = Document(
        page_content="Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure.",
        metadata={"team": "Mumbai Indians"}
    )
doc3 = Document(
        page_content="MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.",
        metadata={"team": "Chennai Super Kings"}
    )
doc4 = Document(
        page_content="Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.",
        metadata={"team": "Mumbai Indians"}
    )
doc5 = Document(
        page_content="Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.",
        metadata={"team": "Chennai Super Kings"}
    )

# %%
docs = [doc1, doc2, doc3, doc4, doc5]

# %%
vector_store = Chroma(
    embedding_function=OpenAIEmbeddings(),
    persist_directory='learn_chroma_db',
    collection_name='sample_ipl'
)

# %% [markdown]
# # Performing CRUD Operations

# %%
vector_store.add_documents(docs)
# Out:
# ['52004adf-1699-4334-839a-57e5f8bc4fc9',
#  '5bc342d0-40b7-4edc-a85d-4e37cff86a05',
#  '6bc6b793-24c0-4bd1-801e-d89cf1a69fe8',
#  '511b8da0-99f4-4127-941c-40a6161a8c40',
#  'a3850312-4dcb-4803-a44c-76d5d16f1fdb']

# %%
# read operation
vector_store.get(include=['embeddings','metadatas','documents'])
# Out:
# {'ids': ['52004adf-1699-4334-839a-57e5f8bc4fc9',
#   '5bc342d0-40b7-4edc-a85d-4e37cff86a05',
#   '6bc6b793-24c0-4bd1-801e-d89cf1a69fe8',
#   '511b8da0-99f4-4127-941c-40a6161a8c40',
#   'a3850312-4dcb-4803-a44c-76d5d16f1fdb'],
#  'embeddings': array([[-0.00210453, -0.00214285,  0.0268    , ..., -0.01707893,
#          -0.00366616,  0.01357884],
#         [-0.00268021, -0.00010323,  0.02815653, ..., -0.01501936,
#           0.00590092, -0.01164922],
#         [ 0.00092799, -0.00476   ,  0.0124662 , ..., -0.01731381,
#           0.00075886,  0.00296567],
#         [-0.02714536,  0.00885395,  0.02699314, ..., -0.02592762,
#           0.00900617, -0.01999116],
#         [-0.01810451,  0.01281202,  0.0347942 , ..., -0.03034012,
#          -0.00595078,  0.00521716]], shape=(5, 1536)),
# ...

# %%
vector_store.get(ids=['5bc342d0-40b7-4edc-a85d-4e37cff86a05'])
# Out:
# {'ids': ['5bc342d0-40b7-4edc-a85d-4e37cff86a05'],
#  'embeddings': None,
#  'documents': ["Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure."],
#  'uris': None,
#  'included': ['metadatas', 'documents'],
#  'data': None,
#  'metadatas': [{'team': 'Mumbai Indians'}]}

# %%
updated_doc1 = Document(
    page_content="Virat Kohli, the former captain of Royal Challengers Bangalore (RCB), is renowned for his aggressive leadership and consistent batting performances. He holds the record for the most runs in IPL history, including multiple centuries in a single season. Despite RCB not winning an IPL title under his captaincy, Kohli's passion and fitness set a benchmark for the league. His ability to chase targets and anchor innings has made him one of the most dependable players in T20 cricket.",
    metadata={"team": "Royal Challengers Bangalore"}
)

# %%
vector_store.update_document(document_id='52004adf-1699-4334-839a-57e5f8bc4fc9',document=updated_doc1)

# %%
vector_store.get(ids= '52004adf-1699-4334-839a-57e5f8bc4fc9')
# Out:
# {'ids': ['52004adf-1699-4334-839a-57e5f8bc4fc9'],
#  'embeddings': None,
#  'documents': ["Virat Kohli, the former captain of Royal Challengers Bangalore (RCB), is renowned for his aggressive leadership and consistent batting performances. He holds the record for the most runs in IPL history, including multiple centuries in a single season. Despite RCB not winning an IPL title under his captaincy, Kohli's passion and fitness set a benchmark for the league. His ability to chase targets and anchor innings has made him one of the most dependable players in T20 cricket."],
#  'uris': None,
#  'included': ['metadatas', 'documents'],
#  'data': None,
#  'metadatas': [{'team': 'Royal Challengers Bangalore'}]}

# %%
vector_store.delete(ids=['52004adf-1699-4334-839a-57e5f8bc4fc9'])

# %%
vector_store.get(include=['embeddings','documents','metadatas'])
# Out:
# {'ids': ['5bc342d0-40b7-4edc-a85d-4e37cff86a05',
#   '6bc6b793-24c0-4bd1-801e-d89cf1a69fe8',
#   '511b8da0-99f4-4127-941c-40a6161a8c40',
#   'a3850312-4dcb-4803-a44c-76d5d16f1fdb'],
#  'embeddings': array([[-0.00268021, -0.00010323,  0.02815653, ..., -0.01501936,
#           0.00590092, -0.01164922],
#         [ 0.00092799, -0.00476   ,  0.0124662 , ..., -0.01731381,
#           0.00075886,  0.00296567],
#         [-0.02714536,  0.00885395,  0.02699314, ..., -0.02592762,
#           0.00900617, -0.01999116],
#         [-0.01810451,  0.01281202,  0.0347942 , ..., -0.03034012,
#          -0.00595078,  0.00521716]], shape=(4, 1536)),
#  'documents': ["Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure.",
# ...

# %% [markdown]
# # SImialrity Search -> (OG use of Vector Stores)

# %%
vector_store.similarity_search(
    query="who among these are bowlers?",
    k=2
)
# Out:
# [Document(id='511b8da0-99f4-4127-941c-40a6161a8c40', metadata={'team': 'Mumbai Indians'}, page_content='Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.'),
#  Document(id='a3850312-4dcb-4803-a44c-76d5d16f1fdb', metadata={'team': 'Chennai Super Kings'}, page_content='Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.')]

# %%
vector_store.similarity_search_with_score(
    query="who among these are bowlers ?",
    k = 2
)

# lesser the score -> more closer it is.
# Out:
# [(Document(id='511b8da0-99f4-4127-941c-40a6161a8c40', metadata={'team': 'Mumbai Indians'}, page_content='Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.'),
#   0.373546302318573),
#  (Document(id='a3850312-4dcb-4803-a44c-76d5d16f1fdb', metadata={'team': 'Chennai Super Kings'}, page_content='Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.'),
#   0.44395095109939575)]

# %%
vector_store.similarity_search_with_score(
    query="Which team does Rohit Sharma Play for ?",
    k = 1
)
# Out:
# [(Document(id='5bc342d0-40b7-4edc-a85d-4e37cff86a05', metadata={'team': 'Mumbai Indians'}, page_content="Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure."),
#   0.3095742166042328)]

# %%
vector_store.similarity_search_with_score(
    query="who is the Captain ?",
    filter={'team' : 'Mumbai Indians'}
)
# Out:
# [(Document(id='5bc342d0-40b7-4edc-a85d-4e37cff86a05', metadata={'team': 'Mumbai Indians'}, page_content="Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure."),
#   0.3913826644420624),
#  (Document(id='511b8da0-99f4-4127-941c-40a6161a8c40', metadata={'team': 'Mumbai Indians'}, page_content='Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.'),
#   0.5174333453178406)]
